# %%
import spacy
import pandas as pd

# %%
df =pd.read_csv('https://raw.githubusercontent.com/codebasics/nlp-tutorials/main/14_word_vectors_spacy_text_classification/Fake_Real_Data.csv')

# %%
df['label_num'] = df['label'].map({'Fake' : 0, 'Real': 1})
df.head()
# Out:
#                                                 Text label  label_num
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...  Fake          0
# 1  U.S. conservative leader optimistic of common ...  Real          1
# 2  Trump proposes U.S. tax overhaul, stirs concer...  Real          1
# 3   Court Forces Ohio To Allow Millions Of Illega...  Fake          0
# 4  Democrats say Trump agrees to work on immigrat...  Real          1

# %%
nlp = spacy.load("en_core_web_lg")

# %%
df['vector']= df.Text.apply(lambda x: nlp(x).vector)

# %%
df.head()

# %%
print(df.vector.size)
print(df.label.size)

# %%
print(df.vector[0])
print(df.vector[0].size, df.vector[1].size, df.vector[9899].size)
print(df.vector[0][0])

# %% [markdown]
# ##Gensim

# %%
import gensim.downloader as api

wv= api.load("word2vec-google-news-300")

# %%
print(wv["food"])
print(wv.similarity(w1="food", w2="eat"))

# %%
from gensim.models import Word2Vec, KeyedVectors
import pandas as pd
import nltk

# %%
df.head()
# Out:
#                                                 Text label  label_num
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...  Fake          0
# 1  U.S. conservative leader optimistic of common ...  Real          1
# 2  Trump proposes U.S. tax overhaul, stirs concer...  Real          1
# 3   Court Forces Ohio To Allow Millions Of Illega...  Fake          0
# 4  Democrats say Trump agrees to work on immigrat...  Real          1

# %%
newsVec= [nltk.word_tokenize(title) for title in df['Text']]

# %% [markdown]
# skipgram

# %%
model = Word2Vec(newsVec, min_count=1, vector_size=300, sg=1)

# %%
model

# %%
model.save("word2vec.model")

model = Word2Vec.load("word2vec.model")

# %%
vector = model.wv[newsVec[0]]
print(vector.size)
# Out:
# 94200

# %%
df.head()
# Out:
#                                                 Text label  label_num
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...  Fake          0
# 1  U.S. conservative leader optimistic of common ...  Real          1
# 2  Trump proposes U.S. tax overhaul, stirs concer...  Real          1
# 3   Court Forces Ohio To Allow Millions Of Illega...  Fake          0
# 4  Democrats say Trump agrees to work on immigrat...  Real          1

# %%
df['vector_2']= df['Text'].apply(lambda x: model.wv.get_mean_vector(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#                                                 Text label  label_num  \
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...  Fake          0
# 1  U.S. conservative leader optimistic of common ...  Real          1
# 2  Trump proposes U.S. tax overhaul, stirs concer...  Real          1
# 3   Court Forces Ohio To Allow Millions Of Illega...  Fake          0
# 4  Democrats say Trump agrees to work on immigrat...  Real          1
#
#                                             vector_2
# 0  [0.009888535, 0.049982857, -0.020497894, 0.009...
# 1  [0.019001149, 0.057972554, -0.016529966, 0.018...
# 2  [0.027877212, 0.04744897, 0.0008081974, 0.0093...
# 3  [0.0064036, 0.05128586, -0.017914515, 0.019432...
# 4  [0.015653268, 0.052231744, -0.011281588, 0.023...

# %%
df['vector_2'][0].size
# Out:
# 300

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test= train_test_split(df['vector_2'], df.label_num, test_size=0.2)

x_train[:2]
# Out:
# 3925    [0.016969893, 0.044704027, -0.0049398965, 0.01...
# 4422    [0.02639262, 0.055609934, -0.01359403, 0.02027...
# Name: vector_2, dtype: object

# %%
import numpy as np

x_train_2d= np.stack(x_train)
x_test_2d= np.stack(x_test)

x_train_2d.shape
# Out:
# (7920, 300)

# %%
x_train_2d[:2]
# Out:
# array([[ 0.01696989,  0.04470403, -0.0049399 ,  0.01952771, -0.01483193,
#         -0.04015526,  0.04971683,  0.06981058,  0.00509168, -0.02447841,
#          0.0062531 , -0.03080145,  0.00503368,  0.00072483, -0.03488218,
#         -0.03422032,  0.04249819,  0.02396558,  0.00212652,  0.00021456,
#         -0.00229481, -0.01144091,  0.03855655,  0.02536898,  0.03218386,
#         -0.01543137, -0.0593467 ,  0.03294964, -0.03162909, -0.05746955,
#          0.00660292,  0.00024356,  0.03769996, -0.01538338, -0.00937818,
#          0.01541084,  0.04786063, -0.03410917, -0.00878159,  0.00156833,
#         -0.03499211, -0.01953335,  0.0153579 , -0.00018182,  0.01973804,
#          0.01938431,  0.01293206,  0.01187576,  0.00960587,  0.04174666,
#          0.01771951,  0.00116185, -0.00851932, -0.00389221, -0.01432044,
#          0.0551915 ,  0.04410065, -0.0121967 ,  0.03091349,  0.00599466,
#         -0.00495872, -0.02731344,  0.02868343,  0.01825003, -0.02418791,
#          0.07106697, -0.00536268,  0.02085987, -0.03569928, -0.00313156,
#          0.02403997,  0.03870494,  0.03526532, -0.02572817,  0.04372969,
#         -0.00431663, -0.0625383 , -0.00094021, -0.0316877 ,  0.01912903,
#         -0.060617  , -0.02234153, -0.00518323,  0.07987131,  0.02102825,
#         -0.01260273,  0.008212  ,  0.02223555,  0.05188411, -0.0041698 ,
#          0.04592761, -0.02983372,  0.07884831, -0.01710216,  0.05041524,
#          0.05641162,  0.01507504, -0.01394026, -0.00467731,  0.04708774,
#          0.01561109,  0.00980943,  0.06628898,  0.03642272,  0.00626389,
#         -0.04471505, -0.01046468, -0.01362626, -0.04944743, -0.0189142 ,
#         -0.01200826, -0.03477249,  0.01521511,  0.025566  , -0.01436934,
#          0.01912803,  0.00892723, -0.02407404,  0.05303686, -0.09639117,
#          0.01862149,  0.03879567,  0.02603211, -0.00622178, -0.01665924,
#          0.05424324, -0.01033696, -0.01131226, -0.0054822 ,  0.02803775,
#          0.04263511,  0.06310318,  0.03051314, -0.06377758,  0.0060455 ,
#          0.04282043,  0.00621449, -0.05368675, -0.02720854, -0.03412208,
#          0.00552902, -0.0232903 , -0.02984478,  0.04172826,  0.05706903,
#         -0.02178706, -0.03892789, -0.04615954,  0.05154765, -0.02323628,
#         -0.00625598, -0.06943993, -0.05040297,  0.01179431,  0.02451633,
#          0.04504855, -0.05023898,  0.01111274,  0.00948044,  0.04545592,
#          0.02142404,  0.00614473, -0.04834889,  0.02010029, -0.01573228,
#          0.02404697, -0.00724743, -0.04433283,  0.03100531,  0.07226753,
#         -0.01130794, -0.00774482,  0.05709493,  0.02271363,  0.04562632,
#          0.01919593, -0.01525597, -0.0225136 , -0.00683268, -0.00201263,
#          0.0081752 ,  0.03591376, -0.08425049, -0.01353046, -0.06427693,
#          0.00619736,  0.07127059,  0.05386819,  0.04125646, -0.0581973 ,
#          0.0107223 ,  0.02130187, -0.07505085, -0.03060395,  0.00451262,
#         -0.01976971, -0.03859714,  0.01782949,  0.02941862, -0.01355054,
#          0.02356436,  0.00247984, -0.02736828,  0.05520267, -0.09228948,
#          0.02244395,  0.0502442 ,  0.02968617, -0.00788399, -0.00327357,
#          0.05458771, -0.0190122 , -0.00991261, -0.01033573,  0.01507712,
#          0.02945577,  0.06087076,  0.03331864, -0.06539562,  0.00524412,
#          0.04116729,  0.0006844 , -0.04755601, -0.03981657, -0.03460086,
#          0.00486785, -0.02900272, -0.03009535,  0.04785685,  0.05890158,
#         -0.02962503, -0.04270839, -0.0394992 ,  0.04795144, -0.03144384,
#          0.00232171, -0.07114404, -0.04810729,  0.01758029,  0.02391757,
#          0.04607254, -0.04229214,  0.00396834,  0.01294916,  0.05221161,
#          0.02597996,  0.01746436, -0.05813849,  0.02941922, -0.01070874,
#          0.01984905, -0.01381552, -0.04162402,  0.03154796,  0.06717903,
#         -0.01251121, -0.00465763,  0.06176744,  0.02995842,  0.03421896,
#          0.00782638, -0.00499373, -0.02098734, -0.00669767, -0.01177111,
#          0.00113171,  0.03329863, -0.07204676, -0.00709981, -0.05983591,
#          0.01776171,  0.07185725,  0.05822346,  0.04843181, -0.05940716,
#          0.01838368,  0.02646171, -0.06806363, -0.02686659,  0.00979033,
#         -0.05643861, -0.01502769, -0.05060284,  0.02754783,  0.01856061,
#         -0.02441414, -0.01597351,  0.00978217,  0.01829436,  0.02227877,
#          0.00907244,  0.01274043,  0.0421532 ,  0.02301348, -0.02296253,
#         -0.00420907, -0.05330326, -0.00375718, -0.0130726 ,  0.04316003,
#         -0.02889717, -0.03869848, -0.09756784, -0.05197944, -0.03277896,
#          0.0506623 , -0.03779058, -0.00445824, -0.10082472, -0.03199536,
#         -0.04220233,  0.01043595, -0.05594483, -0.03845413,  0.00310909,
#          0.01416832, -0.01503694,  0.01189467,  0.03201963, -0.02586218,
#         -0.00186043,  0.00855935, -0.01398208,  0.03103332, -0.08311301,
#          0.02458398, -0.04072892, -0.01424929, -0.00661655,  0.01793239,
#         -0.0671578 ,  0.01512924, -0.02322304, -0.00130057,  0.03181466,
#          0.07093392, -0.00945263,  0.05692224, -0.00379269, -0.01848984,
#         -0.02366705,  0.10308177,  0.00919595, -0.04854744, -0.05209598,
#          0.00286699, -0.00716445,  0.04729864, -0.06954796, -0.03762202,
#         -0.0014445 ,  0.0329131 ,  0.02866556, -0.08527288,  0.00956271,
#         -0.04132156,  0.00838032, -0.01727879,  0.04500609,  0.00695707,
#          0.02100386,  0.03818054,  0.02983745, -0.06520601,  0.02718899,
#         -0.03333094,  0.01969203, -0.01662286,  0.00167747,  0.0002669 ,
#         -0.00141914, -0.04239687,  0.02159419,  0.04462663,  0.0358613 ,
#          0.00956244,  0.08133874,  0.01912394,  0.04336429,  0.10231315,
#          0.03784725,  0.01440178, -0.03222055,  0.0396972 , -0.04148163]],
#       dtype=float32)

# %%
from sklearn.metrics import classification_report

clf= RandomForestClassifier()
clf.fit(x_train_2d, y_train)

y_pred = clf.predict(x_test_2d)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1006
#            1       0.99      1.00      0.99       974
#
#     accuracy                           0.99      1980
#    macro avg       0.99      0.99      0.99      1980
# weighted avg       0.99      0.99      0.99      1980
